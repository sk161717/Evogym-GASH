# %%
from pymap_elites.map_elites import common as cm
cm.draw_voronoi_map(128,'Walker-v0_ME',10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2c83434d6188> in <module>
#       1 from pymap_elites.map_elites import common as cm
# ----> 2 cm.draw_voronoi_map(128,'Walker-v0_ME',10)
#
# ~/katayama/evogym/examples/pymap_elites/map_elites/common.py in draw_voronoi_map(n_niches, experiment_name, generation)
#     345     plt.title("max:"+str(max_score)+" min:"+str(min_score))
#     346     plt.show()
# --> 347
#     348
#     349
#
# ~/katayama/evogym/examples/pymap_elites/map_elites/common.py in bounded_voronoi(bnd, pnts, centroid_score_dict, max_score, min_score)
#     285         # ボロノイ図の計算
#     286         vor = Voronoi(gn_pnts,qhull_options="Qc")
# --> 287
#     288     # 分割する領域をPolygonに
#     289     bnd_poly = Polygon(bnd)
#
# ...

# %%
print(include_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f56c6a0e9b20> in <module>
# ----> 1 print(include_list)
#
# NameError: name 'include_list' is not defined
